# %%
import pandas as pd
# ler um .parquet
df = pd.read_parquet('../data/processed/sinan_esqu_unsup.parquet')
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135084 entries, 0 to 135083
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   ID_AGRAVO                135084 non-null  string
#  1   SG_UF_NOT                135084 non-null  string
#  2   ID_MUNICIP               135084 non-null  string
#  3   ID_UNIDADE               135084 non-null  string
#  4   CS_SEXO                  135084 non-null  string
#  5   CS_GESTANT               135084 non-null  string
#  6   CS_RACA                  135084 non-null  string
#  7   CS_ESCOL_N               135084 non-null  string
#  8   SG_UF                    135084 non-null  string
#  9   TRATAM                   135084 non-null  string
#  10  FORMA                    135084 non-null  string
#  11  COUFINF                  135084 non-null  string
#  12  DOENCA_TRA               135084 non-null  string
# ...

# %%
# checagem de valores nulos ou em branco em todas as colunas
print(df.isnull().sum())
# Out:
# ID_AGRAVO                      0
# SG_UF_NOT                      0
# ID_MUNICIP                     0
# ID_UNIDADE                     0
# CS_SEXO                        0
# CS_GESTANT                     0
# CS_RACA                        0
# CS_ESCOL_N                     0
# SG_UF                          0
# TRATAM                         0
# FORMA                          0
# COUFINF                        0
# DOENCA_TRA                     0
# EVOLUCAO                   52455
# AN_QUALI                   55278
# IDADE_PROCESSADA               0
# delay_notificacao_dias         0
# tempo_encerramento_dias    17177
# dtype: int64
